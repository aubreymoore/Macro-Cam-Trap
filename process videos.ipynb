# %% [markdown]
# # Process Videos
# Finds moving objects in videos
#
# This Jupyter notebook should be opened using the following commands:
#
#     workon jupyter
#     jupyter notebook

# %%
import glob
import os

# %%
search_pattern = '/media/aubrey/461F-1014/vids/*.mp4'

# %%
vids = glob.glob(search_pattern)
for vid in vids:
    filename = os.path.basename(vid)
    cmd = 'python3 motion_detector.py /media/aubrey/461F-1014/vids {}'.format(filename)
    print()
    print(cmd)
    # !{cmd}
# Out:
# python3 motion_detector.py /media/aubrey/461F-1014/vids VID_20190824_222613.mp4
# starting motion detector
# 1000 frames processed
# 2000 frames processed
# 3000 frames processed
# 4000 frames processed
# 5000 frames processed
# 6000 frames processed
# 7000 frames processed
# 8000 frames processed
# 9000 frames processed
# 10000 frames processed
# 11000 frames processed
# 12000 frames processed
# 13000 frames processed
# 14000 frames processed
# 15000 frames processed
# Saving bounding box data to /media/aubrey/461F-1014/vids/VID_20190824_222613_bounding_boxes.csv
# Processing time: 170 seconds
# python3 motion_detector.py /media/aubrey/461F-1014/vids VID_20190824_223439.mp4
# starting motion detector
# 1000 frames processed
# 2000 frames processed
# 3000 frames processed
# 4000 frames processed
# 5000 frames processed
# 6000 frames processed
# 7000 frames processed
# 8000 frames processed
# 9000 frames processed
# 10000 frames processed
# 11000 frames processed
# ...
